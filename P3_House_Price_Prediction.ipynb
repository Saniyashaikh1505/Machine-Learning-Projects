# %% [markdown]
# <a href="https://colab.research.google.com/github/Saniyashaikh1505/Machine-Learning/blob/main/P3_House_Price_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn.datasets
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor
from sklearn import metrics

# %%
house_data = pd.read_csv('/content/Boston_Housing_Data.csv')
house_data.head()
#house_data.describe()
#house_data.shape
# Out:
#    Per_Capita_Crime_Rate  Residential_Land_Zone_Percent  \
# 0                0.00632                           18.0
# 1                0.02731                            0.0
# 2                0.02729                            0.0
# 3                0.03237                            0.0
# 4                0.06905                            0.0
#
#    NonRetail_Business_Acres_Per_Town  Charles_River_Dummy_Variable  \
# 0                               2.31                             0
# 1                               7.07                             0
# 2                               7.07                             0
# 3                               2.18                             0
# 4                               2.18                             0
#
#    Nitric_Oxides_Concentration  Average_Rooms_Per_Dwelling  \
# 0                        0.538                       6.575
# 1                        0.469                       6.421
# ...

# %%
#Check for missing value

house_data.isnull().sum()
# Out:
# Per_Capita_Crime_Rate                            0
# Residential_Land_Zone_Percent                    0
# NonRetail_Business_Acres_Per_Town                0
# Charles_River_Dummy_Variable                     0
# Nitric_Oxides_Concentration                      0
# Average_Rooms_Per_Dwelling                       0
# Owner_Occupied_Homes_Built_Prior_1940_Percent    0
# Distance_To_Employment_Centers                   0
# Index_Of_Accessibility_To_Highways               0
# Property_Tax_Rate_Per_10K                        0
# Pupil_Teacher_Ratio                              0
# 1000_Bk_Residents_Per_Town                       0
# Lower_Status_Population_Percent                  0
# Price                                            0
# dtype: int64

# %%
#Understanding the Co-relation between various features in the dataset - Positive Correlation , Negative Correlations
correlation = house_data.corr()

#Constructing heatmap to understand the corelation
plt.figure(figsize=(10,10))
sns.heatmap(correlation, cbar=True, square=True, fmt='.1f',annot=True, annot_kws={'size':7}, cmap='Blues')
# Out:
# <Axes: >

# %%
#Spliting the data and target(Price)

X=house_data.drop(['Price'],axis=1)
Y=house_data['Price']

print(X)
print(Y)

# %%
#Spliting Training and Test Data

X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size =0.2,random_state=2)

print(X.shape,X_train.shape,X_test.shape)

# %%
#Model Training

model = XGBRegressor()
model.fit(X_train,Y_train)

# %%
#Evalution - Prediction on Training Data

training_data_prediction = model.predict(X_train)
print(training_data_prediction)

# %%
# R Squared error - Prediction on Training Data
score_1 = metrics.r2_score(Y_train,training_data_prediction)
print('R squared error : ',score_1)


# Mean Absolute Error
score_2 = metrics.mean_absolute_error(Y_train,training_data_prediction)
print('Mean Absolute Error : ',score_2)

# %%
#Evalution - Prediction on Test Data

test_data_prediction = model.predict(X_test)
print(test_data_prediction)

# %%
# R Squared error - Prediction on Test Data
score_1 = metrics.r2_score(Y_test,test_data_prediction)
print('R squared error : ',score_1)


# Mean Absolute Error
score_2 = metrics.mean_absolute_error(Y_test,test_data_prediction)
print('Mean Absolute Error : ',score_2)

# %%
# Visulization the actual Price and Predicted Price
plt.scatter(Y_train,training_data_prediction)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Actual Price vs Predicted Price")
plt.show()
